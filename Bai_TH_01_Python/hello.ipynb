# %%
ten = "Do Dong Minh"

# %%
print("Xin chao,", ten)
# Out:
# Xin chao, Do Dong Minh

# %%
print("Day la chuong trinh Python dau tien cua toi.")
# Out:
# Day la chuong trinh Python dau tien cua toi.
